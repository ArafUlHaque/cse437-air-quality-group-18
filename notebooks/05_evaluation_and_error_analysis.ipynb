# %% [markdown]
# # 05 — Final Evaluation and Error Analysis
#
# Evaluate the frozen model once on the untouched test period and compare it with persistence on identical rows.
#
# Read `AGENTS.md` and `PROJECT_PLAN.md` before adding code.

# %% [markdown]
# ## Stage rules
#
# - Do not retune after viewing test results.
# - Lead with PR-AUC and recall; accuracy is secondary.
# - Report overall and per-city performance.
# - Analyze false negatives first.
# - State honestly whether ML beats persistence.

# %%
from pathlib import Path
import os
import subprocess
import sys

REPO_NAME = "cse437-air-quality-group-18"
REPO_URL = "https://github.com/ArafUlHaque/cse437-air-quality-group-18.git"
GIT_BRANCH = "main"  # Change this when working on a feature branch.

if "google.colab" in sys.modules:
    from google.colab import drive
    drive.mount("/content/drive")
    os.chdir("/content")
    repo_dir = Path(REPO_NAME)
    if repo_dir.is_dir():
        subprocess.run(["git", "-C", str(repo_dir), "fetch", "origin"], check=True)
        subprocess.run(["git", "-C", str(repo_dir), "checkout", GIT_BRANCH], check=True)
        subprocess.run(["git", "-C", str(repo_dir), "pull", "--ff-only", "origin", GIT_BRANCH], check=True)
    else:
        subprocess.run(["git", "clone", "--branch", GIT_BRANCH, REPO_URL, str(repo_dir)], check=True)
    os.chdir(repo_dir)
    STORAGE_ROOT = Path("/content/drive/MyDrive/CSE437_air_quality_group_18")
else:
    STORAGE_ROOT = Path(".")

PROJECT_ROOT = Path(".")
if not (PROJECT_ROOT / "src" / "utils.py").is_file():
    raise FileNotFoundError("Run from the repository root or use the Colab setup above.")

from src.utils import ensure_output_directories, get_project_paths, set_random_seed

PATHS = get_project_paths(PROJECT_ROOT, STORAGE_ROOT)
ensure_output_directories(PATHS)
set_random_seed()
print(f"Project root: {PROJECT_ROOT.resolve()}")
print(f"Persistent storage: {STORAGE_ROOT}")
print(f"Raw data folder: {PATHS['raw']}")

# %% [markdown]
# ## Planned sections
#
# 1. Load frozen artifacts and untouched test data
# 2. Persistence and final-model metrics
# 3. PR curves and confusion matrices
# 4. Per-city transfer results
# 5. False-negative and temporal/coverage error analysis
# 6. Limitations, conclusions, and report-ready figures/tables

# %% [markdown]
# ## Work area
#
# Add implementation cells below this point. Do not invent outputs or conclusions.
